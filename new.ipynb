# %%
import pandas as pd

df = pd.read_csv("data/tatasteel_daily.csv")
print(df.columns)
print(df.head())
# Out:
# Index(['Price', 'Close', 'High', 'Low', 'Open', 'Volume', 'MA10', 'MA50'], dtype='object')
#         Price               Close                High                 Low  \
# 0      Ticker        TATASTEEL.NS        TATASTEEL.NS        TATASTEEL.NS
# 1        Date                 NaN                 NaN                 NaN
# 2  2010-03-17  19.279491424560547  19.627198422981298  16.348374148314196
# 3  2010-03-18  19.496044158935547  19.570771133422934  19.218488220815022
# 4  2010-03-19  19.650074005126953  19.688199541260833  19.409118272001905
#
#                  Open        Volume       MA10       MA50
# 0        TATASTEEL.NS  TATASTEEL.NS        NaN        NaN
# 1                 NaN           NaN        NaN        NaN
# 2  16.348374148314196      60062999  18.817405  18.311398
# 3   19.36794094856125      42724073  18.883439  18.314723
# 4  19.535696175496703      36154030  18.963198  18.311764

# %%
print("📊 Columns in CSV:", df.columns.tolist())
# Out:
# 📊 Columns in CSV: ['Price', 'Close', 'High', 'Low', 'Open', 'Volume', 'MA10', 'MA50']

# %%
from env.trading_env import TradingEnv
# ✅ Optional: Print columns for debug
print("📊 Columns:", df.columns.tolist())

# ✅ Keep only the required numeric features
required_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'MA10', 'MA50']
df = df[required_cols]

# Drop rows with NaNs (MA10 and MA50 may contain early NaNs)
df.dropna(inplace=True)

# Convert to float32
df = df.astype('float32')

# ✅ Create and test env
env = TradingEnv(df)
obs = env.reset()
done = False

while not done:
    action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
    env.render()
# Out:
# 📊 Columns: ['Price', 'Close', 'High', 'Low', 'Open', 'Volume', 'MA10', 'MA50']
# Step: 1
# Price: 19.50
# Cash: 100000.00, Stock Held: 0, Total Value: 100000.00
# Step: 2
# Price: 19.65
# Cash: 99980.50, Stock Held: 1, Total Value: 100000.00
# Step: 3
# Price: 19.19
# Cash: 99960.85, Stock Held: 2, Total Value: 100000.15
# Step: 4
# Price: 19.46
# Cash: 99980.04, Stock Held: 1, Total Value: 99999.23
# Step: 5
# Price: 19.47
# Cash: 99999.50, Stock Held: 0, Total Value: 99999.50
# Step: 6
# Price: 19.65
# Cash: 99999.50, Stock Held: 0, Total Value: 99999.50
# Step: 7
# Price: 19.63
# Cash: 99979.85, Stock Held: 1, Total Value: 99999.50
# Step: 8
# Price: 19.36
# Cash: 99960.22, Stock Held: 2, Total Value: 99999.48
# Step: 9
# Price: 19.28
# Cash: 99940.86, Stock Held: 3, Total Value: 99998.94
# Step: 10
# Price: 19.89
# Cash: 99960.14, Stock Held: 2, Total Value: 99998.70
# Step: 11
# Price: 20.69
# Cash: 99960.14, Stock Held: 2, Total Value: 99999.93
# Step: 12
# Price: 20.97
# ...
